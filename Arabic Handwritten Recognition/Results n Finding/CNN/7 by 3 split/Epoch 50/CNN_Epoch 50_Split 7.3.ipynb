# %% [markdown]
# # Arabic Handwritten Characters Recognition using Convolutional Neural Network and Support Vector Machine

# %% [markdown]
# ### COMP6602: Machine Learning I
# ### Khoula K. Al-Kharusi

# %% [markdown]
# Common Imports

# %%
# %pip install np_utils
# %pip install tqdm
# %matplotlib inline

import os
import math
import random
import itertools
import numpy as np
import pandas as pd

import tensorflow as tf
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense,Flatten,MaxPool2D,MaxPooling2D,Conv2D,Dropout,Activation,BatchNormalization,GlobalAveragePooling2D,Input, Lambda
from keras import regularizers
from keras.models import load_model
from keras.utils import to_categorical
from keras.optimizers import Adam

import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from IPython.display import Image, display
from sklearn.cluster import KMeans
from sklearn.utils import shuffle
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import train_test_split, GridSearchCV, HalvingGridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA,NMF, FactorAnalysis
from sklearn.metrics import confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix

import cv2
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm

np.random.seed(2)
sns.set(style='white', context='notebook', palette='deep')
# Out:
# Requirement already satisfied: np_utils in c:\users\arfan\appdata\local\programs\python\python311\lib\site-packages (0.6.0)
# Requirement already satisfied: numpy>=1.0 in c:\users\arfan\appdata\local\programs\python\python311\lib\site-packages (from np_utils) (1.26.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in c:\users\arfan\appdata\local\programs\python\python311\lib\site-packages (4.66.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: colorama in c:\users\arfan\appdata\local\programs\python\python311\lib\site-packages (from tqdm) (0.4.6)

# %% [markdown]
# ## Import data and preprocessing

# %% [markdown]
# Arabic Characters list to map the labels with the letters

# %%
arabic_characters = ['alef', 'beh', 'teh', 'theh', 'jeem', 'hah', 'khah', 'dal', 'thal',
                    'reh', 'zain', 'seen', 'sheen', 'sad', 'dad', 'tah', 'zah', 'ain',
                    'ghain', 'feh', 'qaf', 'kaf', 'lam', 'meem', 'noon', 'heh', 'waw', 'yeh']
arabic_characters
# Out:
# ['alef',
#  'beh',
#  'teh',
#  'theh',
#  'jeem',
#  'hah',
#  'khah',
#  'dal',
#  'thal',
#  'reh',
#  'zain',
#  'seen',
#  'sheen',
#  'sad',
#  'dad',
#  'tah',
#  'zah',
#  'ain',
#  'ghain',
#  'feh',
#  'qaf',
#  'kaf',
#  'lam',
#  'meem',
#  'noon',
#  'heh',
#  'waw',
#  'yeh']

# %% [markdown]
# ## Importing Dataset

# %%
x_train = pd.read_csv(r"C:\Users\arfan\OneDrive\Desktop\Sem 6\CSP650\Dataset\csvTrainImages 13440x1024.csv",header=None).to_numpy()
y_train = pd.read_csv(r"C:\Users\arfan\OneDrive\Desktop\Sem 6\CSP650\Dataset\csvTrainLabel 13440x1.csv", header=None).to_numpy()-1

x_test = pd.read_csv(r"C:\Users\arfan\OneDrive\Desktop\Sem 6\CSP650\Dataset\csvTestImages 3360x1024.csv",header=None).to_numpy()
y_test = pd.read_csv(r"C:\Users\arfan\OneDrive\Desktop\Sem 6\CSP650\Dataset\csvTestLabel 3360x1.csv", header=None,).to_numpy()-1

print("x_train.shape =", x_train.shape)
print("y_train.shape =", y_train.shape)
print("x_test.shape =", x_test.shape)
print("y_test.shape =", y_test.shape)
# Out:
# x_train.shape = (13440, 1024)
# y_train.shape = (13440, 1)
# x_test.shape = (3360, 1024)
# y_test.shape = (3360, 1)

# %%
x_train = x_train.reshape(-1,32,32)
x_test = x_test.reshape(-1,32,32)
x_train = x_train/255
x_test = x_test/255
# for some reason the images are flipped and rotated
# so we transpose each image to be in the correct shape
x_train = np.array([image.T for image in x_train])
x_test = np.array([image.T for image in x_test])

# shuffle
x_train, y_train = shuffle(x_train, y_train)
x_test, y_test = shuffle(x_test, y_test)

print(x_train.shape, x_test.shape)
# Out:
# (13440, 32, 32) (3360, 32, 32)

# %% [markdown]
# ## Displaying Sample Images from Dataset

# %%
ra = np.random.randint(0, 13440, size=25)
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[ra[i]].reshape(32,32),"gray")
    plt.title(arabic_characters[int(y_train[ra[i]][0])], fontsize = 20)
plt.show()

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.3, random_state=2)

# %%
# Converting the class vector in integers to binary class matrix

from keras.utils import to_categorical
y_train = y_train.reshape(-1)
y_val = y_val.reshape(-1)
y_test = y_test.reshape(-1)

y_train_h = to_categorical(y_train)
y_val_h = to_categorical(y_val)
y_test_h = to_categorical(y_test)

print(y_train.shape, y_val.shape, y_test.shape)
print(y_train_h.shape, y_val_h.shape, y_test_h.shape)
# Out:
# (9408,) (4032,) (3360,)
# (9408, 28) (4032, 28) (3360, 28)

# %% [markdown]
# ## Convolutional Neural Network Model

# %% [markdown]
# Using data generater to extend the training set and avoid overfitting

# %%
x_train = x_train.reshape(-1,32,32, 1)
x_val = x_val.reshape(-1,32,32, 1)
x_test = x_test.reshape(-1,32,32, 1)

train_datagen=ImageDataGenerator(
    #rescale=1/255, # Normalize the new images
    zoom_range=0.2, #the amount of zooming u need
    width_shift_range=0.10, # The percentage of Width shifitning
    height_shift_range=0.10, # The percentage of height shifitning
    shear_range=0.1, #Shear angle in counter-clockwise direction in degrees
    fill_mode='nearest',
    rotation_range=20,
)
train_generator=train_datagen.flow(
    x_train ,y_train ,batch_size=64
)

test_datagen=ImageDataGenerator()
test_generator=test_datagen.flow(
    x_val ,y_val ,batch_size=64

)

# %%
earlystop = EarlyStopping(patience=6)
learning_rate_reduction=ReduceLROnPlateau(
    monitor='val_accuracy',
    patience= 3,
    verbose=1,
)
callbacks = [earlystop, learning_rate_reduction]

# %% [markdown]
# **The ConvNet architecture is the same proposed in the paper 'Arabic Handwritten Characters Recognition using Convolutional Neural Network'**

# %% [markdown]
# ![ConvNet Structure](https://www.researchgate.net/profile/Hazem-El-Bakry/publication/313891953/figure/fig4/AS:464684475260928@1487800820810/The-proposed-CNN-for-Arabic-handwritten-character-recognition_W640.jpg)

# %%
# Set the CNN model

from keras import regularizers

model=Sequential()

model.add(Conv2D(80,(5,5),activation='relu',input_shape=(32,32,1)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(5,5),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(1024,activation='relu', name='featurs'))
#model.add(Dropout(0.5))
model.add(Dense(28, kernel_regularizer=keras.regularizers.l2(0.01) ,activation='softmax'))

# %%
model.compile(optimizer= 'adam' ,loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.001,
    decay_steps=10000,
    decay_rate=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 80)        2080
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 80)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 64)        128064
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  featurs (Dense)             (None, 1024)              1639424
#
#  dense (Dense)               (None, 28)                28700
#
# =================================================================
# Total params: 1798268 (6.86 MB)
# Trainable params: 1798268 (6.86 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ## Model Fitting

# %%
model.fit(
    train_generator,
    epochs=50,
    validation_data=test_generator,
    verbose=1,
    #callbacks=callbacks
)
# Out:
# Epoch 1/50
# 147/147 [==============================] - 18s 113ms/step - loss: 2.3622 - accuracy: 0.3411 - val_loss: 1.1180 - val_accuracy: 0.6615
# Epoch 2/50
# 147/147 [==============================] - 17s 113ms/step - loss: 1.2458 - accuracy: 0.6340 - val_loss: 0.8060 - val_accuracy: 0.7726
# Epoch 3/50
# 147/147 [==============================] - 17s 114ms/step - loss: 0.9541 - accuracy: 0.7197 - val_loss: 0.6405 - val_accuracy: 0.8194
# Epoch 4/50
# 147/147 [==============================] - 17s 114ms/step - loss: 0.8000 - accuracy: 0.7716 - val_loss: 0.4911 - val_accuracy: 0.8748
# Epoch 5/50
# 147/147 [==============================] - 17s 118ms/step - loss: 0.7007 - accuracy: 0.8018 - val_loss: 0.5061 - val_accuracy: 0.8594
# Epoch 6/50
# 147/147 [==============================] - 18s 122ms/step - loss: 0.6682 - accuracy: 0.8156 - val_loss: 0.4415 - val_accuracy: 0.8881
# Epoch 7/50
# 147/147 [==============================] - 16s 109ms/step - loss: 0.5868 - accuracy: 0.8378 - val_loss: 0.3799 - val_accuracy: 0.9075
# Epoch 8/50
# 147/147 [==============================] - 16s 108ms/step - loss: 0.5732 - accuracy: 0.8438 - val_loss: 0.3713 - val_accuracy: 0.9107
# Epoch 9/50
# 147/147 [==============================] - 16s 112ms/step - loss: 0.5410 - accuracy: 0.8520 - val_loss: 0.3273 - val_accuracy: 0.9263
# Epoch 10/50
# 147/147 [==============================] - 17s 114ms/step - loss: 0.5084 - accuracy: 0.8598 - val_loss: 0.3551 - val_accuracy: 0.9025
# Epoch 11/50
# 147/147 [==============================] - 17s 116ms/step - loss: 0.4695 - accuracy: 0.8768 - val_loss: 0.3080 - val_accuracy: 0.9276
# Epoch 12/50
# 147/147 [==============================] - 17s 118ms/step - loss: 0.4596 - accuracy: 0.8747 - val_loss: 0.3732 - val_accuracy: 0.8988
# Epoch 13/50
# 147/147 [==============================] - 17s 118ms/step - loss: 0.4404 - accuracy: 0.8824 - val_loss: 0.3282 - val_accuracy: 0.9157
# Epoch 14/50
# 147/147 [==============================] - 18s 119ms/step - loss: 0.4182 - accuracy: 0.8856 - val_loss: 0.2852 - val_accuracy: 0.9333
# Epoch 15/50
# 147/147 [==============================] - 18s 122ms/step - loss: 0.4106 - accuracy: 0.8904 - val_loss: 0.3210 - val_accuracy: 0.9219
# Epoch 16/50
# 147/147 [==============================] - 19s 130ms/step - loss: 0.3831 - accuracy: 0.8981 - val_loss: 0.2833 - val_accuracy: 0.9353
# Epoch 17/50
# 147/147 [==============================] - 19s 128ms/step - loss: 0.3831 - accuracy: 0.8987 - val_loss: 0.2685 - val_accuracy: 0.9397
# Epoch 18/50
# 147/147 [==============================] - 17s 118ms/step - loss: 0.3706 - accuracy: 0.9017 - val_loss: 0.2706 - val_accuracy: 0.9380
# Epoch 19/50
# 147/147 [==============================] - 17s 117ms/step - loss: 0.3713 - accuracy: 0.8981 - val_loss: 0.2366 - val_accuracy: 0.9511
# Epoch 20/50
# 147/147 [==============================] - 17s 115ms/step - loss: 0.3502 - accuracy: 0.9091 - val_loss: 0.3142 - val_accuracy: 0.9149
# Epoch 21/50
# 147/147 [==============================] - 17s 116ms/step - loss: 0.3388 - accuracy: 0.9094 - val_loss: 0.2336 - val_accuracy: 0.9489
# Epoch 22/50
# 147/147 [==============================] - 17s 113ms/step - loss: 0.3295 - accuracy: 0.9136 - val_loss: 0.2569 - val_accuracy: 0.9375
# Epoch 23/50
# 147/147 [==============================] - 16s 112ms/step - loss: 0.3239 - accuracy: 0.9163 - val_loss: 0.3304 - val_accuracy: 0.9159
# Epoch 24/50
# 147/147 [==============================] - 16s 107ms/step - loss: 0.3135 - accuracy: 0.9205 - val_loss: 0.2144 - val_accuracy: 0.9539
# Epoch 25/50
# 147/147 [==============================] - 16s 108ms/step - loss: 0.3106 - accuracy: 0.9238 - val_loss: 0.2950 - val_accuracy: 0.9283
# Epoch 26/50
# 147/147 [==============================] - 16s 110ms/step - loss: 0.3052 - accuracy: 0.9218 - val_loss: 0.2507 - val_accuracy: 0.9427
# Epoch 27/50
# 147/147 [==============================] - 16s 112ms/step - loss: 0.3038 - accuracy: 0.9223 - val_loss: 0.2156 - val_accuracy: 0.9506
# Epoch 28/50
# 147/147 [==============================] - 16s 112ms/step - loss: 0.3020 - accuracy: 0.9235 - val_loss: 0.2028 - val_accuracy: 0.9539
# Epoch 29/50
# 147/147 [==============================] - 16s 111ms/step - loss: 0.2869 - accuracy: 0.9266 - val_loss: 0.2103 - val_accuracy: 0.9556
# Epoch 30/50
# 147/147 [==============================] - 16s 110ms/step - loss: 0.2764 - accuracy: 0.9329 - val_loss: 0.2201 - val_accuracy: 0.9497
# Epoch 31/50
# 147/147 [==============================] - 16s 109ms/step - loss: 0.2760 - accuracy: 0.9336 - val_loss: 0.2384 - val_accuracy: 0.9449
# Epoch 32/50
# 147/147 [==============================] - 16s 107ms/step - loss: 0.2654 - accuracy: 0.9341 - val_loss: 0.2015 - val_accuracy: 0.9516
# Epoch 33/50
# 147/147 [==============================] - 17s 113ms/step - loss: 0.2630 - accuracy: 0.9324 - val_loss: 0.2456 - val_accuracy: 0.9385
# Epoch 34/50
# 147/147 [==============================] - 16s 111ms/step - loss: 0.2575 - accuracy: 0.9360 - val_loss: 0.2089 - val_accuracy: 0.9521
# Epoch 35/50
# 147/147 [==============================] - 17s 114ms/step - loss: 0.2583 - accuracy: 0.9372 - val_loss: 0.1940 - val_accuracy: 0.9554
# Epoch 36/50
# 147/147 [==============================] - 16s 111ms/step - loss: 0.2545 - accuracy: 0.9368 - val_loss: 0.1857 - val_accuracy: 0.9635
# Epoch 37/50
# 147/147 [==============================] - 17s 115ms/step - loss: 0.2656 - accuracy: 0.9318 - val_loss: 0.2017 - val_accuracy: 0.9583
# Epoch 38/50
# 147/147 [==============================] - 18s 121ms/step - loss: 0.2411 - accuracy: 0.9430 - val_loss: 0.1883 - val_accuracy: 0.9554
# Epoch 39/50
# 147/147 [==============================] - 18s 124ms/step - loss: 0.2483 - accuracy: 0.9359 - val_loss: 0.1776 - val_accuracy: 0.9653
# Epoch 40/50
# 147/147 [==============================] - 16s 111ms/step - loss: 0.2367 - accuracy: 0.9428 - val_loss: 0.2146 - val_accuracy: 0.9511
# Epoch 41/50
# 147/147 [==============================] - 16s 111ms/step - loss: 0.2310 - accuracy: 0.9447 - val_loss: 0.1984 - val_accuracy: 0.9551
# Epoch 42/50
# 147/147 [==============================] - 16s 112ms/step - loss: 0.2420 - accuracy: 0.9393 - val_loss: 0.1939 - val_accuracy: 0.9563
# Epoch 43/50
# 147/147 [==============================] - 17s 116ms/step - loss: 0.2317 - accuracy: 0.9424 - val_loss: 0.2187 - val_accuracy: 0.9479
# Epoch 44/50
# 147/147 [==============================] - 16s 110ms/step - loss: 0.2194 - accuracy: 0.9472 - val_loss: 0.2051 - val_accuracy: 0.9492
# Epoch 45/50
# 147/147 [==============================] - 16s 110ms/step - loss: 0.2180 - accuracy: 0.9469 - val_loss: 0.1858 - val_accuracy: 0.9628
# Epoch 46/50
# 147/147 [==============================] - 16s 111ms/step - loss: 0.2176 - accuracy: 0.9475 - val_loss: 0.1863 - val_accuracy: 0.9578
# Epoch 47/50
# 147/147 [==============================] - 16s 112ms/step - loss: 0.2166 - accuracy: 0.9463 - val_loss: 0.1850 - val_accuracy: 0.9616
# Epoch 48/50
# 147/147 [==============================] - 16s 110ms/step - loss: 0.2175 - accuracy: 0.9459 - val_loss: 0.1706 - val_accuracy: 0.9635
# Epoch 49/50
# 147/147 [==============================] - 16s 108ms/step - loss: 0.2176 - accuracy: 0.9486 - val_loss: 0.1865 - val_accuracy: 0.9606
# Epoch 50/50
# 147/147 [==============================] - 16s 109ms/step - loss: 0.2174 - accuracy: 0.9489 - val_loss: 0.1686 - val_accuracy: 0.9638

# %%
losses = pd.DataFrame(model.history.history)
losses[['accuracy','val_accuracy']].plot()
losses[['loss','val_loss']].plot()
# Out:
# <Axes: >

# %%
model.evaluate(test_generator)
# Out:
# 63/63 [==============================] - 1s 22ms/step - loss: 0.1686 - accuracy: 0.9638
# [0.1686401218175888, 0.963789701461792]

# %%
pred = model.predict(x_test)
print(pred.shape)
pred = np.argmax(pred, axis=1)
print(pred)
# Out:
# 105/105 [==============================] - 1s 13ms/step
# (3360, 28)
# [ 4 22 23 ...  8  4 18]

# %%
y_true = np.argmax(y_test_h, axis=1)
cm = confusion_matrix(y_true, pred)

plt.figure(figsize=(20,15))
sns.heatmap(cm, annot=True, fmt="d")
# Out:
# <Axes: >

# %%
model.save('CNN_Epoch50_(7.3).h5')

# %% [markdown]
# ## The Accuracy Report of the CNN model

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96       120
#            1       0.99      0.99      0.99       120
#            2       0.93      0.98      0.96       120
#            3       0.98      0.95      0.97       120
#            4       1.00      0.96      0.98       120
#            5       0.97      0.98      0.98       120
#            6       0.93      0.98      0.96       120
#            7       0.97      0.98      0.98       120
#            8       0.96      0.93      0.95       120
#            9       0.92      0.99      0.96       120
#           10       0.95      0.92      0.93       120
#           11       0.97      1.00      0.98       120
#           12       0.98      0.99      0.99       120
#           13       0.97      0.96      0.96       120
#           14       0.97      0.97      0.97       120
#           15       0.99      0.97      0.98       120
#           16       0.97      0.99      0.98       120
#           17       0.98      0.97      0.98       120
#           18       0.98      0.96      0.97       120
#           19       0.95      0.99      0.97       120
#           20       1.00      0.91      0.95       120
#           21       0.97      0.99      0.98       120
#           22       0.98      0.99      0.98       120
#           23       0.95      0.98      0.97       120
#           24       0.97      0.96      0.96       120
#           25       0.97      0.97      0.97       120
#           26       0.97      0.96      0.97       120
#           27       1.00      0.97      0.99       120
#
#     accuracy                           0.97      3360
#    macro avg       0.97      0.97      0.97      3360
# weighted avg       0.97      0.97      0.97      3360

# %% [markdown]
# ## Misclassification Analysis

# %%
i = 0
plt.figure(figsize = (20, 16))
for j in range (len(y_test)):
    if y_test[j] != pred[j]:
        plt.subplot(6,8,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(x_test[j].reshape(32,32),"gray")
        plt.title('{} -> {}'.format(arabic_characters[int(y_test[j])], arabic_characters[int(pred[j])]), fontsize = 20)
        #plt.xlabel(arabic_characters[int(y_test[j])], fontsize=20)
        i+=1
    if i >= 48:
        break
plt.show()
plt.savefig('misclassified.png')

# %% [markdown]
# ## Prediction of Characters by inputing images

# %%
image_path = r'C:\Users\arfan\OneDrive\Desktop\Sem 6\CSP650\Dataset\Test Images 3360x32x32\test\sad\id_475_label_14.png'
model_path = r'c:\Users\arfan\OneDrive\Desktop\Sem 6\CSP650\Results n Finding\CNN\7 by 3 split\Epoch 50\CNN_Epoch50_(7.3).h5'

import cv2

def predict_image(image_path, model_path):
    # Load the model
    # model = load_model(model_path)

    # Load and preprocess the image
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (32, 32))
    img = img.reshape(1, 32, 32, 1)
    img = img.astype('float32') / 255.0

    # Make the prediction
    pred = model.predict(img)
    predicted_label = arabic_characters[np.argmax(pred)]

    return predicted_label

def plot_image(image_path):
    # Load the image
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Plot the image
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.show()

prediction = predict_image(image_path, model_path)
print('Predicted label:', prediction)
plot_image(image_path)
# Out:
# 1/1 [==============================] - 0s 97ms/step
# Predicted label: sad
