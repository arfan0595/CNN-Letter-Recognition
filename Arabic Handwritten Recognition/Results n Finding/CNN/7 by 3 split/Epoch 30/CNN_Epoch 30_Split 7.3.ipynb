# %%
# Arabic Handwritten Characters Recognition using Convolutional Neural Network and Support Vector Machine

# %% [markdown]
# ### COMP6602: Machine Learning I
# ### Khoula K. Al-Kharusi

# %% [markdown]
# Common Imports

# %%
# %pip install np_utils
# %pip install tqdm
# %matplotlib inline

import os
import math
import random
import itertools
import numpy as np
import pandas as pd

import tensorflow as tf
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense,Flatten,MaxPool2D,MaxPooling2D,Conv2D,Dropout,Activation,BatchNormalization,GlobalAveragePooling2D,Input, Lambda
from keras import regularizers
from keras.models import load_model
from keras.utils import to_categorical
from keras.optimizers import Adam

import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from IPython.display import Image, display
from sklearn.cluster import KMeans
from sklearn.utils import shuffle
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import train_test_split, GridSearchCV, HalvingGridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA,NMF, FactorAnalysis
from sklearn.metrics import confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix

import cv2
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm

np.random.seed(2)
sns.set(style='white', context='notebook', palette='deep')
# Out:
# Requirement already satisfied: np_utils in c:\users\arfan\appdata\local\programs\python\python311\lib\site-packages (0.6.0)
# Requirement already satisfied: numpy>=1.0 in c:\users\arfan\appdata\local\programs\python\python311\lib\site-packages (from np_utils) (1.26.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in c:\users\arfan\appdata\local\programs\python\python311\lib\site-packages (4.66.1)
# Requirement already satisfied: colorama in c:\users\arfan\appdata\local\programs\python\python311\lib\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import data and preprocessing

# %% [markdown]
# Arabic Characters list to map the labels with the letters

# %%
arabic_characters = ['alef', 'beh', 'teh', 'theh', 'jeem', 'hah', 'khah', 'dal', 'thal',
                    'reh', 'zain', 'seen', 'sheen', 'sad', 'dad', 'tah', 'zah', 'ain',
                    'ghain', 'feh', 'qaf', 'kaf', 'lam', 'meem', 'noon', 'heh', 'waw', 'yeh']
arabic_characters
# Out:
# ['alef',
#  'beh',
#  'teh',
#  'theh',
#  'jeem',
#  'hah',
#  'khah',
#  'dal',
#  'thal',
#  'reh',
#  'zain',
#  'seen',
#  'sheen',
#  'sad',
#  'dad',
#  'tah',
#  'zah',
#  'ain',
#  'ghain',
#  'feh',
#  'qaf',
#  'kaf',
#  'lam',
#  'meem',
#  'noon',
#  'heh',
#  'waw',
#  'yeh']

# %% [markdown]
# ## Importing Dataset

# %%
x_train = pd.read_csv(r"C:\Users\arfan\OneDrive\Desktop\Sem 6\CSP650\Dataset\csvTrainImages 13440x1024.csv",header=None).to_numpy()
y_train = pd.read_csv(r"C:\Users\arfan\OneDrive\Desktop\Sem 6\CSP650\Dataset\csvTrainLabel 13440x1.csv", header=None).to_numpy()-1

x_test = pd.read_csv(r"C:\Users\arfan\OneDrive\Desktop\Sem 6\CSP650\Dataset\csvTestImages 3360x1024.csv",header=None).to_numpy()
y_test = pd.read_csv(r"C:\Users\arfan\OneDrive\Desktop\Sem 6\CSP650\Dataset\csvTestLabel 3360x1.csv", header=None,).to_numpy()-1

print("x_train.shape =", x_train.shape)
print("y_train.shape =", y_train.shape)
print("x_test.shape =", x_test.shape)
print("y_test.shape =", y_test.shape)
# Out:
# x_train.shape = (13440, 1024)
# y_train.shape = (13440, 1)
# x_test.shape = (3360, 1024)
# y_test.shape = (3360, 1)

# %%
x_train = x_train.reshape(-1,32,32)
x_test = x_test.reshape(-1,32,32)
x_train = x_train/255
x_test = x_test/255
# for some reason the images are flipped and rotated
# so we transpose each image to be in the correct shape
x_train = np.array([image.T for image in x_train])
x_test = np.array([image.T for image in x_test])

# shuffle
x_train, y_train = shuffle(x_train, y_train)
x_test, y_test = shuffle(x_test, y_test)

print(x_train.shape, x_test.shape)
# Out:
# (13440, 32, 32) (3360, 32, 32)

# %% [markdown]
# ## Displaying Sample Images from Dataset

# %%
ra = np.random.randint(0, 13440, size=25)
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[ra[i]].reshape(32,32),"gray")
    plt.title(arabic_characters[int(y_train[ra[i]][0])], fontsize = 20)
plt.show()

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.3)

# %%
# Converting the class vector in integers to binary class matrix

from keras.utils import to_categorical
y_train = y_train.reshape(-1)
y_val = y_val.reshape(-1)
y_test = y_test.reshape(-1)

y_train_h = to_categorical(y_train)
y_val_h = to_categorical(y_val)
y_test_h = to_categorical(y_test)

print(y_train.shape, y_val.shape, y_test.shape)
print(y_train_h.shape, y_val_h.shape, y_test_h.shape)
# Out:
# (9408,) (4032,) (3360,)
# (9408, 28) (4032, 28) (3360, 28)

# %% [markdown]
# ## Convolutional Neural Network Model

# %% [markdown]
# Using data generater to extend the training set and avoid overfitting

# %%
x_train = x_train.reshape(-1,32,32, 1)
x_val = x_val.reshape(-1,32,32, 1)
x_test = x_test.reshape(-1,32,32, 1)

train_datagen=ImageDataGenerator(
    #rescale=1/255, # Normalize the new images
    zoom_range=0.2, #the amount of zooming u need
    width_shift_range=0.10, # The percentage of Width shifitning
    height_shift_range=0.10, # The percentage of height shifitning
    shear_range=0.1, #Shear angle in counter-clockwise direction in degrees
    fill_mode='nearest',
    rotation_range=20,
)
train_generator=train_datagen.flow(
    x_train ,y_train ,batch_size=64
)

test_datagen=ImageDataGenerator()
test_generator=test_datagen.flow(
    x_val ,y_val ,batch_size=64

)

# %%
earlystop = EarlyStopping(patience=6)
learning_rate_reduction=ReduceLROnPlateau(
    monitor='val_accuracy',
    patience= 3,
    verbose=1,
)
callbacks = [earlystop, learning_rate_reduction]

# %% [markdown]
# **The ConvNet architecture is the same proposed in the paper 'Arabic Handwritten Characters Recognition using Convolutional Neural Network'**

# %% [markdown]
# ![ConvNet Structure](https://www.researchgate.net/profile/Hazem-El-Bakry/publication/313891953/figure/fig4/AS:464684475260928@1487800820810/The-proposed-CNN-for-Arabic-handwritten-character-recognition_W640.jpg)

# %%
# Set the CNN model

from keras import regularizers

model=Sequential()

model.add(Conv2D(80,(5,5),activation='relu',input_shape=(32,32,1)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(5,5),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(1024,activation='relu', name='featurs'))
#model.add(Dropout(0.5))
model.add(Dense(28, kernel_regularizer=keras.regularizers.l2(0.01) ,activation='softmax'))

# %%
model.compile(optimizer= 'adam' ,loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.00 1,
    decay_steps=10000,
    decay_rate=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 80)        2080
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 80)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 64)        128064
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  featurs (Dense)             (None, 1024)              1639424
#
#  dense (Dense)               (None, 28)                28700
#
# =================================================================
# Total params: 1798268 (6.86 MB)
# Trainable params: 1798268 (6.86 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ## Model Fitting

# %%
model.fit(
    train_generator,
    epochs=30,
    validation_data=test_generator,
    verbose=1,
    #callbacks=callbacks
)
# Out:
# Epoch 1/30
# 147/147 [==============================] - 18s 114ms/step - loss: 2.3141 - accuracy: 0.3529 - val_loss: 1.0770 - val_accuracy: 0.6796
# Epoch 2/30
# 147/147 [==============================] - 17s 114ms/step - loss: 1.1735 - accuracy: 0.6608 - val_loss: 0.7168 - val_accuracy: 0.7994
# Epoch 3/30
# 147/147 [==============================] - 17s 115ms/step - loss: 0.9072 - accuracy: 0.7402 - val_loss: 0.5866 - val_accuracy: 0.8440
# Epoch 4/30
# 147/147 [==============================] - 17s 116ms/step - loss: 0.7871 - accuracy: 0.7752 - val_loss: 0.6084 - val_accuracy: 0.8251
# Epoch 5/30
# 147/147 [==============================] - 17s 116ms/step - loss: 0.7072 - accuracy: 0.8009 - val_loss: 0.5049 - val_accuracy: 0.8681
# Epoch 6/30
# 147/147 [==============================] - 18s 120ms/step - loss: 0.6364 - accuracy: 0.8223 - val_loss: 0.4877 - val_accuracy: 0.8611
# Epoch 7/30
# 147/147 [==============================] - 16s 107ms/step - loss: 0.5982 - accuracy: 0.8317 - val_loss: 0.3931 - val_accuracy: 0.9048
# Epoch 8/30
# 147/147 [==============================] - 16s 106ms/step - loss: 0.5583 - accuracy: 0.8464 - val_loss: 0.3586 - val_accuracy: 0.9127
# Epoch 9/30
# 147/147 [==============================] - 16s 109ms/step - loss: 0.5067 - accuracy: 0.8630 - val_loss: 0.3829 - val_accuracy: 0.8981
# Epoch 10/30
# 147/147 [==============================] - 16s 109ms/step - loss: 0.5139 - accuracy: 0.8599 - val_loss: 0.3900 - val_accuracy: 0.8909
# Epoch 11/30
# 147/147 [==============================] - 16s 108ms/step - loss: 0.4794 - accuracy: 0.8689 - val_loss: 0.3558 - val_accuracy: 0.9110
# Epoch 12/30
# 147/147 [==============================] - 16s 108ms/step - loss: 0.4529 - accuracy: 0.8808 - val_loss: 0.3778 - val_accuracy: 0.8956
# Epoch 13/30
# 147/147 [==============================] - 16s 108ms/step - loss: 0.4347 - accuracy: 0.8818 - val_loss: 0.2986 - val_accuracy: 0.9286
# Epoch 14/30
# 147/147 [==============================] - 16s 107ms/step - loss: 0.4159 - accuracy: 0.8891 - val_loss: 0.3256 - val_accuracy: 0.9167
# Epoch 15/30
# 147/147 [==============================] - 16s 108ms/step - loss: 0.4048 - accuracy: 0.8924 - val_loss: 0.3202 - val_accuracy: 0.9164
# Epoch 16/30
# 147/147 [==============================] - 16s 109ms/step - loss: 0.3955 - accuracy: 0.8939 - val_loss: 0.3146 - val_accuracy: 0.9204
# Epoch 17/30
# 147/147 [==============================] - 16s 108ms/step - loss: 0.3714 - accuracy: 0.9040 - val_loss: 0.2741 - val_accuracy: 0.9318
# Epoch 18/30
# 147/147 [==============================] - 16s 108ms/step - loss: 0.3624 - accuracy: 0.9065 - val_loss: 0.2525 - val_accuracy: 0.9395
# Epoch 19/30
# 147/147 [==============================] - 16s 108ms/step - loss: 0.3627 - accuracy: 0.9047 - val_loss: 0.2660 - val_accuracy: 0.9333
# Epoch 20/30
# 147/147 [==============================] - 17s 116ms/step - loss: 0.3431 - accuracy: 0.9098 - val_loss: 0.2468 - val_accuracy: 0.9405
# Epoch 21/30
# 147/147 [==============================] - 17s 115ms/step - loss: 0.3594 - accuracy: 0.9026 - val_loss: 0.2308 - val_accuracy: 0.9504
# Epoch 22/30
# 147/147 [==============================] - 17s 116ms/step - loss: 0.3271 - accuracy: 0.9150 - val_loss: 0.2461 - val_accuracy: 0.9437
# Epoch 23/30
# 147/147 [==============================] - 17s 116ms/step - loss: 0.3115 - accuracy: 0.9209 - val_loss: 0.2132 - val_accuracy: 0.9524
# Epoch 24/30
# 147/147 [==============================] - 17s 117ms/step - loss: 0.3129 - accuracy: 0.9212 - val_loss: 0.2468 - val_accuracy: 0.9425
# Epoch 25/30
# 147/147 [==============================] - 17s 116ms/step - loss: 0.2923 - accuracy: 0.9275 - val_loss: 0.2100 - val_accuracy: 0.9521
# Epoch 26/30
# 147/147 [==============================] - 17s 116ms/step - loss: 0.3032 - accuracy: 0.9235 - val_loss: 0.2392 - val_accuracy: 0.9457
# Epoch 27/30
# 147/147 [==============================] - 17s 117ms/step - loss: 0.2981 - accuracy: 0.9221 - val_loss: 0.2168 - val_accuracy: 0.9469
# Epoch 28/30
# 147/147 [==============================] - 17s 117ms/step - loss: 0.2952 - accuracy: 0.9242 - val_loss: 0.1942 - val_accuracy: 0.9616
# Epoch 29/30
# 147/147 [==============================] - 17s 116ms/step - loss: 0.2814 - accuracy: 0.9273 - val_loss: 0.2332 - val_accuracy: 0.9437
# Epoch 30/30
# 147/147 [==============================] - 17s 118ms/step - loss: 0.2701 - accuracy: 0.9322 - val_loss: 0.2180 - val_accuracy: 0.9519

# %%
losses = pd.DataFrame(model.history.history)
losses[['accuracy','val_accuracy']].plot()
losses[['loss','val_loss']].plot()
# Out:
# <Axes: >

# %%
model.evaluate(test_generator)
# Out:
# 63/63 [==============================] - 2s 25ms/step - loss: 0.2180 - accuracy: 0.9519
# [0.21795567870140076, 0.951884925365448]

# %%
pred = model.predict(x_test)
print(pred.shape)
pred = np.argmax(pred, axis=1)
print(pred)
# Out:
# 105/105 [==============================] - 2s 13ms/step
# (3360, 28)
# [ 4 22 23 ...  8  4 18]

# %%
y_true = np.argmax(y_test_h, axis=1)
cm = confusion_matrix(y_true, pred)

plt.figure(figsize=(20,15))
sns.heatmap(cm, annot=True, fmt="d")
# Out:
# <Axes: >

# %%
model.save('CNN.h5')

# %% [markdown]
# ## The Accuracy Report of the CNN model

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       120
#            1       1.00      0.97      0.99       120
#            2       0.83      0.97      0.90       120
#            3       0.94      0.95      0.95       120
#            4       0.99      0.95      0.97       120
#            5       0.93      0.96      0.94       120
#            6       0.93      0.96      0.95       120
#            7       0.96      0.91      0.94       120
#            8       0.85      0.97      0.90       120
#            9       0.91      0.98      0.94       120
#           10       0.99      0.81      0.89       120
#           11       1.00      0.99      1.00       120
#           12       0.96      0.99      0.98       120
#           13       0.97      0.98      0.98       120
#           14       0.98      0.97      0.97       120
#           15       0.97      0.95      0.96       120
#           16       0.95      0.97      0.96       120
#           17       0.98      0.86      0.92       120
#           18       0.89      0.99      0.94       120
#           19       0.96      0.85      0.90       120
#           20       0.88      0.95      0.91       120
#           21       0.96      0.97      0.97       120
#           22       0.97      0.99      0.98       120
#           23       0.98      0.98      0.98       120
#           24       0.97      0.82      0.89       120
#           25       0.94      0.99      0.96       120
#           26       1.00      0.92      0.96       120
#           27       0.98      1.00      0.99       120
#
#     accuracy                           0.95      3360
#    macro avg       0.95      0.95      0.95      3360
# weighted avg       0.95      0.95      0.95      3360

# %% [markdown]
# ## Misclassification Analysis

# %%
i = 0
plt.figure(figsize = (20, 16))
for j in range (len(y_test)):
    if y_test[j] != pred[j]:
        plt.subplot(6,8,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(x_test[j].reshape(32,32),"gray")
        plt.title('{} -> {}'.format(arabic_characters[int(y_test[j])], arabic_characters[int(pred[j])]), fontsize = 20)
        #plt.xlabel(arabic_characters[int(y_test[j])], fontsize=20)
        i+=1
    if i >= 48:
        break
plt.show()
plt.savefig('misclassified.png')

# %% [markdown]
# ## Prediction of Characters by inputing images

# %%
image_path = r'C:\Users\arfan\OneDrive\Desktop\Sem 6\CSP650\Dataset\Test Images 3360x32x32\test\sad\id_475_label_14.png'
model_path = r'C:\Users\arfan\OneDrive\Desktop\Sem 6\CSP650\Source Code\updated coding\CNN.h5'

import cv2

def predict_image(image_path, model_path):
    # Load the model
    # model = load_model(model_path)

    # Load and preprocess the image
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (32, 32))
    img = img.reshape(1, 32, 32, 1)
    img = img.astype('float32') / 255.0

    # Make the prediction
    pred = model.predict(img)
    predicted_label = arabic_characters[np.argmax(pred)]

    return predicted_label

def plot_image(image_path):
    # Load the image
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Plot the image
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.show()

prediction = predict_image(image_path, model_path)
print('Predicted label:', prediction)
plot_image(image_path)
# Out:
# 1/1 [==============================] - 0s 71ms/step
# Predicted label: sad
